# %% [markdown]
# # SVM-based Eye Detection
# ## Use an SVM to detect eyes, given a training image and mask.

# %%
import BasicFunctions as bf
import numpy as np
from scipy import signal
from skimage import feature
from skimage import transform
from sklearn import svm
from sklearn import preprocessing
from collections import deque

# %matplotlib inline

# %%
img = bf.imread("obama.jpg")
img = bf.rgb2gray(img)
bf.imshow(img)

# %%
# positive exemplars
eye1_tl = (200, 480)
eye2_tl = (195, 655)

eye1 = img[200:225, 480:530]
bf.imshow(eye1)

eye2 = img[195:220, 655:705]
bf.imshow(eye2)

eye_shape = eye1.shape
print eye_shape

eye1_hog, hog_vis = feature.hog(eye1, pixels_per_cell=(8, 8), cells_per_block=(6, 3), visualise=True)
print eye1_hog.shape, hog_vis.shape
bf.imshow(hog_vis)
# Out:
# (25, 50)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d5684a103c9e> in <module>()
#      12 print eye_shape
#      13
# ---> 14 eye1_hog, hog_vis = feature.hog(eye1, pixels_per_cell=(8, 8), cells_per_block=(3, 6), visualise=True)
#      15 print eye1_hog.shape, hog_vis.shape
#      16 bf.imshow(hog_vis)
#
# /Users/davidfridovichkeil/anaconda/lib/python2.7/site-packages/skimage/feature/_hog.pyc in hog(image, orientations, pixels_per_cell, cells_per_block, visualise, normalise)
#     172     n_blocksy = (n_cellsy - by) + 1
#     173     normalised_blocks = np.zeros((n_blocksy, n_blocksx,
# --> 174                                   by, bx, orientations))
#     175
#     176     for x in range(n_blocksx):
#
# ValueError: negative dimensions are not allowed

# %%
def overlapsEye(tl):
    if (((tl[0] < eye1_tl[0]-eye_shape[0]) or (tl[0] > eye1_tl[0]+eye_shape[0])) and
        ((tl[0] < eye2_tl[0]-eye_shape[0]) or (tl[0] > eye2_tl[0]+eye_shape[0])) and
        ((tl[1] < eye1_tl[1]-eye_shape[1]) or (tl[1] > eye1_tl[1]+eye_shape[1])) and
        ((tl[1] < eye2_tl[1]-eye_shape[1]) or (tl[1] > eye2_tl[1]+eye_shape[1]))):
        return False
    return True

def isValid(tl):
    if (tl[0] < img.shape[0]-eye_shape[0]) and (tl[1] < img.shape[1]-eye_shape[1]) and not overlapsEye(tl):
        return True
    return False
    
def extractTL(tl):
    return img[tl[0]:tl[0]+eye_shape[0], tl[1]:tl[1]+eye_shape[1]]
    
# negative exemplars from rest of image
negs = []
num_negs = 0
while num_negs < 100:
    tl = (np.random.randint(0, img.shape[0]), np.random.randint(0, img.shape[1]))
    if isValid(tl):
        num_negs += 1
        negs.append(extractTL(tl))

# %%
def jitter(patch):
    f = 10.0
    
    # translate so center is at top left (origin)
    tf = np.matrix([[1, 0, -round(3.5 * eye_shape[1])],
                    [0, 1, -round(3.5 * eye_shape[0])],
                    [0, 0, 1]])
    
    # scale
    tf = np.matrix([[1/f, 0, 0],
                    [0, 1/f, 0],
                    [0, 0, 1]]) * tf
    
    # rotate about z
    theta = 0.05*np.random.randn()
    tf = np.matrix([[np.cos(theta), -np.sin(theta), 0],
                   [np.sin(theta), np.cos(theta), 0],
                   [0, 0, 1]]) * tf

    # now rotate about x
    theta = 0.05*np.random.randn()
    tf = np.matrix([[1, 0, 0],
                    [0, np.cos(theta), -np.sin(theta)],
                    [0, np.sin(theta), np.cos(theta)]]) * tf

    # now rotate about y
    theta = 0.05*np.random.randn()
    tf = np.matrix([[np.cos(theta), 0, np.sin(theta)],
                   [0, 1, 0],
                   [-np.sin(theta), 0, np.cos(theta)]]) * tf

    # scale back
    tf = np.matrix([[f, 0, 0],
                    [0, f, 0],
                    [0, 0, 1]]) * tf
    
    # translate back
    tf = np.matrix([[1, 0, round(3.5 * eye_shape[1])],
                    [0, 1, round(3.5 * eye_shape[0])],
                    [0, 0, 1]]) * tf
                    
    return transform.warp(patch, tf)

def eye2patch(tl):
    return img[tl[0]-3*eye_shape[0]:tl[0]+4*eye_shape[0], 
               tl[1]-3*eye_shape[1]:tl[1]+4*eye_shape[1]]

def patch2eye(patch):
    return patch[3*eye_shape[0]:-3*eye_shape[0], 3*eye_shape[1]:-3*eye_shape[1]]

# create more positive exemplars by applying random small 3D rotations to each eye
eyes = [eye1, eye2]
num_eyes = len(eyes)
patches = deque([eye2patch(eye1_tl), eye2patch(eye2_tl)])
while num_eyes < 100:
    patch = patches.popleft()
    jittered = jitter(patch)
    patches.append(patch)
    eyes.append(patch2eye(jittered))
    num_eyes += 1

# %%
for n in range(20):
    bf.imshow(eyes[n])

# %%
# compute HOG for eyes and negs
eyes_hog = []
for eye in eyes:
    eyes_hog.append(feature.hog(eye))

negs_hog = []
for neg in negs:
    negs_hog.append(feature.hog(neg))

# %%
# set up training dataset
training_set = np.vstack((eyes_hog, negs_hog))

training_labels = np.ones(num_eyes + num_negs)
training_labels[num_eyes:] = 0

scaler = preprocessing.StandardScaler().fit(training_set)
training_set = scaler.transform(training_set)

# %%
# train SVM
weights = {0 : 1.0, 1 : 1.0}
clf = svm.SVC(C=1.0, gamma=0.1, kernel="rbf", class_weight=weights)
clf.fit(training_set, training_labels)
# Out:
# SVC(C=1.0, cache_size=200, class_weight={0: 1.0, 1: 1.0}, coef0=0.0, degree=3,
#   gamma=0.1, kernel='rbf', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)

# %%
def testWindow(tl):
    window = extractTL(tl)
    window_hog = scaler.transform(feature.hog(window))
    label = clf.predict(window_hog)
    score = clf.decision_function(window_hog)
    return score

def flat2ind(n):
    ncol = img.shape[1] - eye_shape[1]
    i = n / ncol
    j = n % ncol
    return (i, j)

# test SVM on sliding window
scores = map(lambda n : testWindow(flat2ind(n)), range(0, (img.shape[0]-eye_shape[0])*(img.shape[1]-eye_shape[1])))

# %%
scores = np.array(scores).reshape((img.shape[0]-eye_shape[0], img.shape[1]-eye_shape[1]))
matches = np.zeros(scores.shape)
matches[scores > 0] = 1.0
display = 0.25*img
display[:scores.shape[0], :scores.shape[1]] += 0.75*matches
bf.imshow(display, cbar=True)

# %%
print scores[scores>0]
# Out:
# [ 0.00649386  0.16127242  0.99983479  0.1795829   0.00599975  0.17984612
#   0.01560816  0.03009415  0.19427662  1.00012878  0.17761454  0.04695241]

# %%
print np.where(scores>0.9)
# Out:
# (array([195, 200]), array([655, 480]))
