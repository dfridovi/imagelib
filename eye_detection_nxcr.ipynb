# %% [markdown]
# # Pattern Matching Eye Detection
# ## Use normalized cross-correlation to detect eyes, given a training image and mask.

# %%
import BasicFunctions as bf
import numpy as np
import scipy as sp

# %matplotlib inline

# %%
img = bf.imread("obama.jpg")
bf.imshow(img)

# %%
eye = img[200:225, 480:530]
bf.imshow(eye)

# %%
img_norm = img
eye_norm =
